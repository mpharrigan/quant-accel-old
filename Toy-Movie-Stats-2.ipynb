# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as pp
from toymovie import toy
import pickle
from toymovie.toy import *

# %%
cd ~/projects/toy-movie-local/
# Out:
# /home/harrigan/projects/toy-movie-local

# %%
with open('quant_results2.pickl', 'r') as f:
    c = pickle.load(f)

# %% [markdown]
# Fitting the gold standard
# --------
# The first implied timescale at the conclusion of a long, non-adaptive-sampled simulation is used as the gold standard. *'Error'* is defined as the difference with this gold standard value. We fit the error with a single exponential.

# %%
gold_popt = tfit(c.gold, p0=(1,1e3))
pp.xlabel('Walltime')
pp.ylabel('Error')
pp.title("'Gold' single long trajectory error convergence.")
# Out:
# [  1.10697236e+00   1.99775860e+03]

# %% [markdown]
# We also fit exponentials to the adaptive sampling methods. In the first case, we varied the length per trajectory (*lpt*). In the second case, we varried the number of parallel (*ll*) trajectories per round.

# %%
for toy in c.lpt_list:
    tfit(toy, p0=(6,20))
pp.xlabel('Walltime')
pp.ylabel('Error')
pp.legend()
pp.show()
# Out:
# [ 6.61541534  9.44704567]
# [  6.56585246  17.28633371]
# [  5.26073054  36.57589578]
# [  6.24892925  22.58801429]

# %%
for toy in c.ll_list[5:]:
    tfit(toy, p0 = (8,5))
pp.legend(ncol=3)
pp.show()
# Out:
# [  5.85051579  10.19559479]
# [  4.96880153  18.86096294]
# [ 6.42936626  5.3056775 ]
# [ 4.72378053  7.24729338]
# [ 8.47868102  3.62673105]
# [ 6.05983423  6.05081342]
# [ 6.68871033  3.62819916]
# [  5.51765484  12.05922415]
# [ 8.3796009   3.12819999]

# %% [markdown]
# We can calculate speedup given a particular error cutoff.

# %%
plot_speedup_bar(c.lpt_list, gold_popt, "Length per trajectory", lpt_dir_to_x, p0=(6,20), error_val=0.5)
# Out:
# ['quant/lpt-run/lpt-1000-30', 'quant/lpt-run/lpt-2000-15', 'quant/lpt-run/lpt-6000-5', 'quant/lpt-run/lpt-30000-1']
# [65.079313831960462, 35.669955910824235, 18.445643297575675, 27.83251150991271]

# %%
plot_speedup_bar(c.ll_list, gold_popt, "Number of parallel simulations", ll_dir_to_x, width=0.2, error_val=0.5)
# Out:
# ['quant/parallelism-run/ll-1', 'quant/parallelism-run/ll-2', 'quant/parallelism-run/ll-3', 'quant/parallelism-run/ll-5', 'quant/parallelism-run/ll-6', 'quant/parallelism-run/ll-7', 'quant/parallelism-run/ll-10', 'quant/parallelism-run/ll-14', 'quant/parallelism-run/ll-15', 'quant/parallelism-run/ll-21', 'quant/parallelism-run/ll-30', 'quant/parallelism-run/ll-35', 'quant/parallelism-run/ll-42', 'quant/parallelism-run/ll-70']
# [11.915444203340691, 2290.6683643504966, 18.399386442564108, 31.133984542260457, 64.820489621452907, 63.313674658105846, 36.659603718183448, 117.17152660257668, 97.554585522484672, 154.66019650694523, 105.17987597152451, 168.73350146020218, 54.835099303789399, 180.05529902739954]

# %% [markdown]
# Statistics
# --------
# Run identical simulation 100 times, see the difference in implied timescale.

# %%
with open('quant_results.stat.pickl') as f:
    c2 = pickle.load(f)

# %%
xs = c2.stat_list[0].errors[:,0]
ys = np.zeros((len(xs), len(c2.stat_list)))
for i in xrange(len(c2.stat_list)):
    ys[:,i] = c2.stat_list[i].errors[:,1]
    
yavg = np.average(ys, axis=1)
ystd = np.std(ys, axis=1)

# %%
stat = LPT('stat')
stat.errors = np.zeros((len(xs)-1,2))
stat.errors[:,0] = xs[1:]
stat.errors[:,1] = yavg[1:]

# %%
pp.errorbar(xs, yavg, yerr=ystd)
tfit(stat, p0=(5, 10))
pp.ylim(ymin=0)
pp.xlabel('Walltime')
pp.ylabel('Errors')
pp.title('Error with uncertainty.')
pp.show()
# Out:
# [  5.33652181  17.36504902]
